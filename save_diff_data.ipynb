# %% [markdown]
# # Load diff package (shift+enter)

# %%
from nanorsm_v2 import *

# %% [markdown]
# # Enter logfiles and parameters here

# %%
# load elemental image data, align it with pystackreg and generate a tranform matrix
#put xrf data with a filena

#logfiles = ['//data//users//current_user/Find_ideal_theta_scan_startID330770.csv']
logfiles = glob.glob('//data//users//current_user//Fe5GeTe2_ladybug_0018*.csv')
diff_detector = 'merlin1'
norm_with = 'sclr1_ch4' #or None
compression = 'gzip' #or gzip or None
print(logfiles)
# Out:
# ['//data//users//current_user/Fe5GeTe2_ladybug_0018_overnight_startID331446.csv', '//data//users//current_user/Fe5GeTe2_ladybug_0018_overnight_startID331440.csv']

# %% [markdown]
# # Start Batch Export

# %%
for logfile in logfiles:

    export_diff_h5_log_file(logfile, 
                            diff_detector = diff_detector, 
                            compression = compression)
# Out:
# [331446 331447 331448 331449 331450 331451 331452 331453 331454 331455
#  331456 331457 331458 331459]
# h5 files will be saved to //data/users/current_user/Fe5GeTe2_ladybug_0018_overnight_startID331446_diff_data
# Progress:   0%|          | 0/14 [00:00<?, ?it/s]
# sid = 331446
# data size = 6.98 GB
# saved_as ='//data/users/current_user/Fe5GeTe2_ladybug_0018_overnight_startID331446_diff_data/scan_331446_merlin1'
# sid = 331447
# data size = 6.98 GB
# saved_as ='//data/users/current_user/Fe5GeTe2_ladybug_0018_overnight_startID331446_diff_data/scan_331447_merlin1'
# sid = 331448
# data size = 6.98 GB
# saved_as ='//data/users/current_user/Fe5GeTe2_ladybug_0018_overnight_startID331446_diff_data/scan_331448_merlin1'
# sid = 331449
# data size = 6.98 GB
# saved_as ='//data/users/current_user/Fe5GeTe2_ladybug_0018_overnight_startID331446_diff_data/scan_331449_merlin1'
# sid = 331450
# data size = 6.98 GB
# ...
